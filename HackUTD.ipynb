# %%
import pandas as pd

# %%
d1 = pd.read_csv('ex-client.csv')
# Out:
#    transaction_id  product_id  customer_id  quantity transaction_date  \
# 0            1001           1            1         2        11/1/2024
# 1            1002           2            2         1        11/2/2024
# 2            1003           3            1         3        11/3/2024
# 3            1004           1            2         5        11/4/2024
# 4            1005           2            3         2        11/5/2024
# 5            1006           3            4         1        11/6/2024
# 6            1007           1            3         4        11/7/2024
# 7            1008           3            2         2        11/8/2024
# 8            1009           2            1         3        11/9/2024
# 9            1010           3            3         6       11/10/2024
#
#    total_amount  product_id.1 product_name  category_id  supplier_id  ...  \
# 0            30             1     Widget A          101            1  ...
# 1            25             2     Widget B          102            2  ...
# 2           105             3     Widget C          103            1  ...
# 3            75             4     widget D          104            4  ...
# 4            50             5     Widget E          105            4  ...
# 5            35             6     Widget F          106            2  ...
# 6            60             7     Widget G          107            1  ...
# 7            70             8     Widget H          108            3  ...
# 8            75             9     Widget I          109            4  ...
# 9           210            10     Widget J          110            1  ...
#
#     category_name  custAmt_purchase  adjustment_id  product_id.2  \
# 0      home_decor                10           2001             1
# 1     electronics                25           2002             2
# 2         clothes                33           2003             3
# 3      room_decor                16           2004             1
# 4    kitchen_ware                17           2005             2
# 5           clean                22           2006             3
# 6  bathroom_suppl                40           2007             1
# 7            pets                55           2008             3
# 8     outer_decor                35           2009             2
# 9  seasonal_items                48           2010             1
#
#   adjustment_type quantity_adjusted  adjustment_date  Unnamed: 22  \
# 0   replenishment                15        11/1/2024          NaN
# 1       depletion                 5        11/2/2024          NaN
# 2   replenishment                10        11/3/2024          NaN
# 3       depletion                 3        11/4/2024          NaN
# 4   replenishment                20        11/5/2024  supplier_id
# 5       depletion                 2        11/6/2024            1
# 6   replenishment                25        11/7/2024            2
# 7   replenishment                15        11/8/2024            3
# 8       depletion                10        11/9/2024            4
# 9       depletion                 4       11/10/2024          NaN
#
#          Unnamed: 23                     Unnamed: 24
# 0                NaN                             NaN
# 1                NaN                             NaN
# 2                NaN                             NaN
# 3                NaN                             NaN
# 4      supplier_name                  supplier_email
# 5           SupplyCo            supplyco@example.com
# 6  Home Goods Direct           homegoods@example.com
# 7            PetLife               petlife.gmail.com
# 8  AnthropologyFauna  anthropology.fauna@outlook.com
# 9                NaN                             NaN
#
# [10 rows x 25 columns]

# %%
d1.info()
d1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   transaction_id     10 non-null     int64
#  1   product_id         10 non-null     int64
#  2   customer_id        10 non-null     int64
#  3   quantity           10 non-null     int64
#  4   transaction_date   10 non-null     object
#  5   total_amount       10 non-null     int64
#  6   product_id.1       10 non-null     int64
#  7   product_name       10 non-null     object
#  8   category_id        10 non-null     int64
#  9   supplier_id        10 non-null     int64
#  10  price              10 non-null     int64
#  11  stock_level        10 non-null     int64
#  12  reorder_point      10 non-null     int64
#  13  cost               10 non-null     int64
#  14  category_id.1      10 non-null     object
#  15  category_name      10 non-null     object
#  16  custAmt_purchase   10 non-null     int64
#  17  adjustment_id      10 non-null     int64
#  18  product_id.2       10 non-null     int64
#  19  adjustment_type    10 non-null     object
#  20  quantity_adjusted  10 non-null     int64
#  21  adjustment_date    10 non-null     object
#  22  Unnamed: 22        5 non-null      object
#  23  Unnamed: 23        5 non-null      object
#  24  Unnamed: 24        5 non-null      object
# dtypes: int64(16), object(9)
# memory usage: 2.1+ KB
#        transaction_id  product_id  customer_id  quantity  total_amount  \
# count        10.00000   10.000000    10.000000  10.00000     10.000000
# mean       1005.50000    2.100000     2.200000   2.90000     73.500000
# std           3.02765    0.875595     1.032796   1.66333     53.854227
# min        1001.00000    1.000000     1.000000   1.00000     25.000000
# 25%        1003.25000    1.250000     1.250000   2.00000     38.750000
# 50%        1005.50000    2.000000     2.000000   2.50000     65.000000
# 75%        1007.75000    3.000000     3.000000   3.75000     75.000000
# max        1010.00000    3.000000     4.000000   6.00000    210.000000
#
#        product_id.1  category_id  supplier_id      price  stock_level  \
# count      10.00000     10.00000    10.000000  10.000000    10.000000
# mean        5.50000    105.50000     2.300000  15.600000    24.000000
# std         3.02765      3.02765     1.337494   8.733079    11.254629
# min         1.00000    101.00000     1.000000   8.000000    10.000000
# 25%         3.25000    103.25000     1.000000  10.000000    16.250000
# 50%         5.50000    105.50000     2.000000  12.500000    22.500000
# 75%         7.75000    107.75000     3.750000  18.750000    28.750000
# max        10.00000    110.00000     4.000000  35.000000    50.000000
#
#        reorder_point       cost  custAmt_purchase  adjustment_id  \
# count      10.000000  10.000000         10.000000       10.00000
# mean        6.100000  10.400000         30.100000     2005.50000
# std         1.969207   4.880801         14.670075        3.02765
# min         4.000000   6.000000         10.000000     2001.00000
# 25%         4.250000   7.250000         18.250000     2003.25000
# 50%         6.000000   9.000000         29.000000     2005.50000
# 75%         7.000000  11.250000         38.750000     2007.75000
# max        10.000000  20.000000         55.000000     2010.00000
#
#        product_id.2  quantity_adjusted
# count     10.000000          10.000000
# mean       1.900000          10.900000
# std        0.875595           7.752419
# min        1.000000           2.000000
# 25%        1.000000           4.250000
# 50%        2.000000          10.000000
# 75%        2.750000          15.000000
# max        3.000000          25.000000

# %%
import pandas as pd

# Load your dataset
data = pd.read_csv('ex-client.csv')

# Ensure that the 'product_id' and 'quantity' columns exist in your dataset
# You can check the actual column names in your DataFrame
#print(data.columns)

# Aggregate the total quantity sold per product
product_sales = data.groupby('product_id')['quantity'].sum().reset_index()

# Sort the products by the total quantity sold
sorted_sales = product_sales.sort_values(by='quantity', ascending=False)

# Display the most sold and least sold products
most_sold = sorted_sales.iloc[0]
least_sold = sorted_sales.iloc[-1]

print(f"Most sold item: Product ID {most_sold['product_id']} with quantity {most_sold['quantity']}")
print(f"Least sold item: Product ID {least_sold['product_id']} with quantity {least_sold['quantity']}")
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'quantity',
#        'transaction_date', 'total_amount', 'product_id.1', 'product_name',
#        'category_id', 'supplier_id', 'price', 'stock_level', 'reorder_point',
#        'cost', 'category_id.1', 'category_name', 'custAmt_purchase',
#        'adjustment_id', 'product_id.2', 'adjustment_type', 'quantity_adjusted',
#        'adjustment_date', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')
# Most sold item: Product ID 3 with quantity 12
# Least sold item: Product ID 2 with quantity 6

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Create sample data if you don't have it
# Remove this section if you already have your data
data = pd.DataFrame({
    'product_id': range(100),
    'quantity': np.random.randint(1, 100, 100),
    'cluster': np.random.randint(0, 3, 100)
})

# Assign colors to clusters for better visualization
colors = ['red', 'blue', 'green']

# Create the plot
plt.figure(figsize=(10, 6))

# Plot each cluster
for cluster_id in range(3):  # Adjust range if the number of clusters changes
    cluster_data = data[data['cluster'] == cluster_id]  # Fixed indexing
    plt.scatter(
        cluster_data['product_id'],
        cluster_data['quantity'],
        label=f'Cluster {cluster_id}',
        color=colors[cluster_id],
        alpha=0.6,
        edgecolors='black'
    )

# Add labels and title
plt.title('Clusters of Products')
plt.xlabel('Product ID')
plt.ylabel('Quantity')
plt.legend()
plt.grid(True)
plt.show()
